# %%
import numpy as np
import pandas as pd

# %%
from lencoder import ColumnOneHotEncoder, OneHotEncoder

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train.columns.values,
# Out:
# (array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object),)

# %%
test.columns.values
# Out:
# array(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
train['train'] = True
test['train'] = False

# %%
all_data = pd.concat([train, test])

# %%
all_data['Pclass'] = all_data['Pclass'].astype('str')

# %% [markdown]
# ### Pclass
#
# `Pclass` does not have nans.

# %% [markdown]
# So we can encode it without nan.

# %%
ohe = OneHotEncoder(items=all_data['Pclass'], colname='Pclass', add_nan=False)

# %%
cohe = ColumnOneHotEncoder(items=all_data['Pclass'], colname='Pclass', add_nan=False)

# %%
cohe.item2num

# %%
cohe.create_dicts().encode(all_data)
# Out:
#        Age        Cabin Embarked      Fare  \
# 0     22.0          NaN        S    7.2500
# 1     38.0          C85        C   71.2833
# 2     26.0          NaN        S    7.9250
# 3     35.0         C123        S   53.1000
# 4     35.0          NaN        S    8.0500
# 5      NaN          NaN        Q    8.4583
# 6     54.0          E46        S   51.8625
# 7      2.0          NaN        S   21.0750
# 8     27.0          NaN        S   11.1333
# 9     14.0          NaN        C   30.0708
# 10     4.0           G6        S   16.7000
# 11    58.0         C103        S   26.5500
# 12    20.0          NaN        S    8.0500
# 13    39.0          NaN        S   31.2750
# 14    14.0          NaN        S    7.8542
# 15    55.0          NaN        S   16.0000
# 16     2.0          NaN        Q   29.1250
# 17     NaN          NaN        S   13.0000
# 18    31.0          NaN        S   18.0000
# 19     NaN          NaN        C    7.2250
# 20    35.0          NaN        S   26.0000
# ...

# %%
all_data = all_data
